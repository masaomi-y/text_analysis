# %% [markdown]
# <a href="https://colab.research.google.com/github/JGS2020-012/text_analysis/blob/master/setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 参考URL：https://qiita.com/opankopan/items/33947d776afdc4cca784

# JUMAN
# 参考　https://teratail.com/questions/186997
# !wget "http://nlp.ist.i.kyoto-u.ac.jp/nl-resource/juman/juman-7.01.tar.bz2"
# !bzip2 -dc juman-7.01.tar.bz2 | tar xvf -
# %cd juman-7.01/
# !./configure
# !make
# !make install
# %cd ..
# !ldconfig
# Out:
# --2020-02-24 12:33:53--  http://nlp.ist.i.kyoto-u.ac.jp/nl-resource/juman/juman-7.01.tar.bz2
# Resolving nlp.ist.i.kyoto-u.ac.jp (nlp.ist.i.kyoto-u.ac.jp)... 133.3.252.171
# Connecting to nlp.ist.i.kyoto-u.ac.jp (nlp.ist.i.kyoto-u.ac.jp)|133.3.252.171|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4286891 (4.1M) [application/x-bzip2]
# Saving to: ‘juman-7.01.tar.bz2’
#
# juman-7.01.tar.bz2  100%[===================>]   4.09M   644KB/s    in 6.8s
#
# 2020-02-24 12:34:00 (616 KB/s) - ‘juman-7.01.tar.bz2’ saved [4286891/4286891]
#
# juman-7.01/
# juman-7.01/aclocal.m4
# juman-7.01/AUTHORS
# juman-7.01/autodic/
# juman-7.01/autodic/Auto.dic
# juman-7.01/autodic/Makefile.am
# juman-7.01/autodic/Makefile.in
# juman-7.01/ChangeLog
# juman-7.01/config.guess
# juman-7.01/config.h.in
# juman-7.01/config.sub
# juman-7.01/configure
# juman-7.01/configure.ac
# juman-7.01/COPYING
# juman-7.01/depcomp
# juman-7.01/dic/
# juman-7.01/dic/Assert.dic
# ...

# %%
# KNPのインストール
# https://www.utali.io/entry/2016/10/20/202744
# http://nlp.ist.i.kyoto-u.ac.jp/index.php?KNP%2F%E3%82%A4%E3%83%B3%E3%82%B9%E3%83%88%E3%83%BC%E3%83%AB%E6%96%B9%E6%B3%95

! wget http://nlp.ist.i.kyoto-u.ac.jp/nl-resource/knp/knp-4.19.tar.bz2
! tar jxvf knp-4.19.tar.bz2
% cd knp-4.19
# !./configure
# !make
# !make install
# Out:
# --2020-02-24 12:39:39--  http://nlp.ist.i.kyoto-u.ac.jp/nl-resource/knp/knp-4.19.tar.bz2
# Resolving nlp.ist.i.kyoto-u.ac.jp (nlp.ist.i.kyoto-u.ac.jp)... 133.3.252.171
# Connecting to nlp.ist.i.kyoto-u.ac.jp (nlp.ist.i.kyoto-u.ac.jp)|133.3.252.171|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 799622946 (763M) [application/x-bzip2]
# Saving to: ‘knp-4.19.tar.bz2’
#
# knp-4.19.tar.bz2    100%[===================>] 762.58M   651KB/s    in 20m 7s
#
# 2020-02-24 12:59:46 (647 KB/s) - ‘knp-4.19.tar.bz2’ saved [799622946/799622946]
#
# knp-4.19/
# knp-4.19/aclocal.m4
# knp-4.19/AUTHORS
# knp-4.19/autogen.sh
# knp-4.19/cdb/
# knp-4.19/ChangeLog
# knp-4.19/compile
# knp-4.19/config.guess
# knp-4.19/config.h.in
# knp-4.19/config.sub
# knp-4.19/configure
# knp-4.19/configure.ac
# knp-4.19/COPYING
# knp-4.19/crf/
# knp-4.19/CRF++-0.58/
# knp-4.19/depcomp
# knp-4.19/dict/
# knp-4.19/distsim/
# knp-4.19/doc/
# knp-4.19/INSTALL
# knp-4.19/install-sh
# ...

# %%
# pyKNP
# ! pip install pyknp
# Out:
# ERROR: Could not find a version that satisfies the requirement urllib2 (from versions: none)
# ERROR: No matching distribution found for urllib2

# %%
# 実行サンプル
# https://blog.imind.jp/entry/2019/01/12/192936
from pyknp import Juman
juman = Juman(jumanpp=False)

text = "LINEpay使えない店でもpayカードならクレカ扱ってるとこはどこでも使えるし便利だよ〜考えてみて！"
result = juman.analysis(text)
 
for mrph in result.mrph_list():
    # midashi, genkei, yomi, hinshiなど指定できる
    print (mrph.genkei)
# Out:
# LINEpay
# 使える
# ない
# 店
# でも
# pay
# カード
# なら
# クレカ
# 扱う
# る
# とこ
# は
# どこ
# でも
# 使える
# し
# 便利だ
# よ
# 考える
# みる
# ！
